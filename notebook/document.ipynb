# %% [markdown]
# ### DATA Ingestion

# %%
### document structure

from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the content of the document, I'm using to create RAG",
    metadata={
        "source": "example.pdf", 
        "page": 1,
        "author": "Mohit Sen",
        "datecreated": "2026-03-24"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.pdf', 'page': 1, 'author': 'Mohit Sen', 'datecreated': '2026-03-24'}, page_content="This is the content of the document, I'm using to create RAG")

# %%
## creating a simple text file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_text = {
    "../data/text_files/python_intro.txt": "This is the content of sample text file 1."
}
for filepath, content in sample_text.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)
print("Sample text file created successfully.")
# Out:
# Sample text file created successfully.

# %%
### Textloader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='This is the content of sample text file 1.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

directory_loader = DirectoryLoader(
    "../data/text_files", 
    glob="**/*.txt", 
    loader_cls=TextLoader,
    loader_kwargs={"encoding": "utf-8"},
    show_progress=False

)

documents = directory_loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='This is the content of sample text file 1.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

directory_loader = DirectoryLoader(
    "../data/pdf", 
    glob="**/*.pdf", 
    loader_cls=PyMuPDFLoader,
    show_progress=False

)

pdf_docs = directory_loader.load()
print(pdf_docs)
# Out:
# [Document(metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': '..\\data\\pdf\\kaushik blood report.pdf', 'file_path': '..\\data\\pdf\\kaushik blood report.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2025-08-22T14:35:53+00:00', 'trapped': '', 'modDate': 'D:20250822143553Z', 'creationDate': '', 'page': 0}, page_content='DIAGNOSTIC REPORT\nMAKAN NO. 0189 ANDHIYARI BAGH, SOUTH THANA\nTIWARIPUR,GORAKHPUR\nPATIENT NAME :  ADITYA KAUSHIK\nPATIENT ID       : ADITM406605810\nACCESSION NO : 0185YE006091\nAGE/SEX    :20 Years\nMale\nABHA NO          :\nDRAWN      :25/05/2025 10:46:36\nRECEIVED  : 25/05/2025 12:33:12\nREPORTED  :25/05/2025 14:42:41\nREF. DOCTOR :  SELF\nCLIENT PATIENT ID:\nCODE/NAME & ADDRESS  : C000141270\nANDHIYARI BAGH COLLECTION CENTRE\nGORAKHPUR 273001\n8081533776\nFinal\nResults\nBiological Reference Interval\nTest Report Status\nUnits\nBIOCHEMISTRY\nBLOOD GLUCOSE RANDOM RWA\n
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader, CSVLoader 

directory_loader = DirectoryLoader(
    "../data/excel", 
    glob="**/*.csv", 
    loader_cls=CSVLoader,
    show_progress=False

)

csv_docs = directory_loader.load()
print(csv_docs)
# Out:
# [Document(metadata={'source': '..\\data\\excel\\Customer - Copy.csv', 'row': 0}, page_content='customer_Id: 268408\nDOB: 02-01-1970\nGender: M\ncity_code: 4'), Document(metadata={'source': '..\\data\\excel\\Customer - Copy.csv', 'row': 1}, page_content='customer_Id: 269696\nDOB: 07-01-1970\nGender: F\ncity_code: 8'), Document(metadata={'source': '..\\data\\excel\\Customer - Copy.csv', 'row': 2}, page_content='customer_Id: 268159\nDOB: 08-01-1970\nGender: F\ncity_code: 8'), Document(metadata={'source': '..\\data\\excel\\Customer - Copy.csv', 'row': 3}, page_content='customer_Id: 270181\nDOB: 10-01-1970\nGender: F\ncity_code: 2'), Document(metadata={'source': '..\\data\\excel\\Customer - Copy.csv', 'row': 4}, page_content='customer_Id: 268073\nDOB: 11-01-1970\nGender: M\ncity_code: 1'), Document(metadata={'source': '..\\data\\excel\\Customer - Copy.csv', 'row': 5}, page_content='customer_Id: 273216\nDOB: 15-01-1970\nGender: F\ncity_code: 5'), Document(metadata={'source': '..\\data\\exc
# ...
